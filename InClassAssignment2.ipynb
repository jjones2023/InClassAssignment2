# %% [markdown]
# #In Class Assignment 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/newhousing.csv")

# %%
data.head()
# Out:
#      price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  5250000  5500         3          2        1         1          0         1
# 1  4480000  4040         3          1        2         1          0         0
# 2  3570000  3640         2          1        1         1          0         0
# 3  2870000  3040         2          1        1         0          0         0
# 4  3570000  4500         2          1        1         0          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  semi-furnished  \
# 0                0                0        0         0               1
# 1                0                0        1         0               1
# 2                0                0        0         0               0
# 3                0                0        0         0               0
# 4                0                0        0         0               0
#
#    unfurnished  areaperbedroom   bbratio
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            545 non-null    int64
#  1   area             545 non-null    int64
#  2   bedrooms         545 non-null    int64
#  3   bathrooms        545 non-null    int64
#  4   stories          545 non-null    int64
#  5   mainroad         545 non-null    int64
#  6   guestroom        545 non-null    int64
#  7   basement         545 non-null    int64
#  8   hotwaterheating  545 non-null    int64
#  9   airconditioning  545 non-null    int64
#  10  parking          545 non-null    int64
#  11  prefarea         545 non-null    int64
#  12  semi-furnished   545 non-null    int64
#  13  unfurnished      545 non-null    int64
#  14  areaperbedroom   545 non-null    float64
#  15  bbratio          545 non-null    float64
# dtypes: float64(2), int64(14)
# memory usage: 68.2 KB

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'semi-furnished', 'unfurnished',
#        'areaperbedroom', 'bbratio'],
#       dtype='object')

# %% [markdown]
# ## Splitting the Data

# %%
X = data.drop('price', axis = 1)
y = data[['price']]

# %% [markdown]
# ##Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, 
                                                    random_state = 0)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components= 2)
pca.fit(X_scaled)
x_pca = pca.transform(X_scaled)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
regressor.score(X_train, y_train)
# Out:
# 0.7207292197818493

# %%
regressor.score(X_test, y_test)
# Out:
# 0.5481622196535569

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
RFG = RandomForestRegressor()
RFG.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor()

# %%
RFG.score(X_train, y_train)
# Out:
# 0.9493403902064194

# %%
RFG.score(X_test, y_test)
# Out:
# 0.528963476560675

# %% [markdown]
# ## PCA Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_pca, y, test_size = 0.3,
                                                    random_state = 0)

# %% [markdown]
# ## PCA with Linear Regression

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_train, y_train)
# Out:
# 0.6717632678848646

# %%
regressor.score(X_test, y_test)
# Out:
# 0.5699901167619912

# %% [markdown]
# ## PCA with Random Forest Regression

# %%
RFG.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor()

# %%
RFG.score(X_train, y_train)
# Out:
# 0.9420518883799532

# %%
RFG.score(X_test, y_test)
# Out:
# 0.475063532883774

# %% [markdown]
# ### For the experiment I found Random Forest to be the best model for housing price calculation with a score of 95% though the model may be overfitted. In that case the best model would be Linear Regression with a score of 72%
